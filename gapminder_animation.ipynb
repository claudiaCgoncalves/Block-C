# %%
# libraries
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import seaborn as sns
sns.set_style("white")
import pandas as pd
my_dpi=96

# %%
# Get the data (csv file is hosted on the web)
# Importar os dados através do url
url = 'https://python-graph-gallery.com/wp-content/uploads/gapminderData.csv'
data = pd.read_csv(url)
#data=pd.read_csv('gapminderData.csv')
data.head()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %%
# And I need to transform my categorical column (continent) in a numerical value group1->1, group2->2...

# Cada Continente representa, através de uma categoria 'continent', um valor -> número

data['continent']=pd.Categorical(data['continent'])

# %%
# %matplotlib notebook
# %matplotlib notebook


# For each year:

# Definir o ano como elemento único
# Desenvolver uma sequência em loop para executar o código até que este a data(ano) acabe

for i in data.year.unique():
 
# Configurar o gráfico
# initialize a figure
    fig=plt.figure(figsize=(680/my_dpi, 480/my_dpi), dpi=my_dpi)
 
# Definir elementos como as coordenadas, escala, cor, transparência, cor da borda exterior e espessura da linha.
# Change color with c and alpha. I map the color to the X axis value.
    tmp=data[ data.year == i ]
    plt.scatter(tmp['lifeExp'], tmp['gdpPercap'] , s=tmp['pop']/200000 , c=tmp['continent'].cat.codes, cmap="Accent", alpha=0.6, edgecolors="white", linewidth=2)
 
# Definir títulos e limites
# Add titles (main and on axis)
    plt.yscale('log')
    plt.xlabel("Life Expectancy")
    plt.ylabel("GDP per Capita")
    plt.title("Year: "+str(i) )
    plt.ylim(0,100000)
    plt.xlim(30, 90)
 

# Gravar cada imagem desenvolvido com o nome "Gapminder_step" + "ano" + ".png"
# Save it
    filename='Gapminder_step'+str(i)+'.png'
    plt.savefig(filename, dpi=96)
    plt.gca()

#Transformation in a GIF using Image Magick
    

# Then use image magick (this is bash, not python)
#magick convert -delay 80 Gapminder*.png animated_gapminder.gif
# Out:
# <img src="data:image/png;base64,..." width="678.8889068733032">
# C:\Users\tiago\anaconda3\lib\site-packages\ipykernel_launcher.py:20: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
# <img src="data:image/png;base64,..." width="678.8889068733032">
# <img src="data:image/png;base64,..." width="678.8889068733032">
# <img src="data:image/png;base64,..." width="678.8889068733032">
# <img src="data:image/png;base64,..." width="678.8889068733032">
# <img src="data:image/png;base64,..." width="678.8889068733032">
# <img src="data:image/png;base64,..." width="678.8889068733032">
# <img src="data:image/png;base64,..." width="678.8889068733032">
# <img src="data:image/png;base64,..." width="678.8889068733032">
# <img src="data:image/png;base64,..." width="678.8889068733032">
# <img src="data:image/png;base64,..." width="678.8889068733032">
# <img src="data:image/png;base64,..." width="678.8889068733032">
